# %% [markdown]
# #  Scraper
# Our goal in this notebook is to scrape data for house sales in the city of Thesaloniki. We will scrape data from the biggest Greek website for house sales: spitogatos.gr. First we import all the necessary libraries. We are going to use selenium for the scraping.

# %%
import pandas as pd
import os
import httpx
from selenium import webdriver
from selenium.webdriver.common.by import By
import numpy as np
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import WebDriverException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import time
import datetime
import logging
from fake_useragent import UserAgent

# %% [markdown]
# We initiate a webdriver element

# %%
driver=webdriver.Chrome()

# %% [markdown]
# We create a dictionary with all the years from 1952 to 2023 as keys and all the webpages containing the houses for sale that were built in that year in Thessaloniki.

# %%
html_files_years1952_2023={}
for i in range(1952,2024):
    url_solo=f"https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-{i}/etos_kataskevis_eos-{i}?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14" 
    
    
    html_files_years1952_2023[i]=url_solo
html_files_years1952_2023
# Out:
# {1952: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1952/etos_kataskevis_eos-1952?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1953: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1953/etos_kataskevis_eos-1953?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1954: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1954/etos_kataskevis_eos-1954?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1955: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1955/etos_kataskevis_eos-1955?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1956: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1956/etos_kataskevis_eos-1956?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1957: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1957/etos_kataskevis_eos-1957?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1958: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1958/etos_kataskevis_eos-1958?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1959: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1959/etos_kataskevis_eos-1959?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1960: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1960/etos_kataskevis_eos-1960?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1961: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1961/etos_kataskevis_eos-1961?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1962: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1962/etos_kataskevis_eos-1962?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1963: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1963/etos_kataskevis_eos-1963?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1964: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1964/etos_kataskevis_eos-1964?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1965: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1965/etos_kataskevis_eos-1965?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1966: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1966/etos_kataskevis_eos-1966?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1967: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1967/etos_kataskevis_eos-1967?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1968: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1968/etos_kataskevis_eos-1968?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1969: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1969/etos_kataskevis_eos-1969?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1970: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1970/etos_kataskevis_eos-1970?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1971: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1971/etos_kataskevis_eos-1971?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1972: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1972/etos_kataskevis_eos-1972?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1973: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1973/etos_kataskevis_eos-1973?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1974: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1974/etos_kataskevis_eos-1974?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1975: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1975/etos_kataskevis_eos-1975?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1976: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1976/etos_kataskevis_eos-1976?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1977: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1977/etos_kataskevis_eos-1977?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1978: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1978/etos_kataskevis_eos-1978?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1979: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1979/etos_kataskevis_eos-1979?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1980: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1980/etos_kataskevis_eos-1980?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1981: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1981/etos_kataskevis_eos-1981?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1982: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1982/etos_kataskevis_eos-1982?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1983: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1983/etos_kataskevis_eos-1983?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1984: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1984/etos_kataskevis_eos-1984?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1985: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1985/etos_kataskevis_eos-1985?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1986: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1986/etos_kataskevis_eos-1986?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1987: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1987/etos_kataskevis_eos-1987?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1988: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1988/etos_kataskevis_eos-1988?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1989: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1989/etos_kataskevis_eos-1989?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1990: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1990/etos_kataskevis_eos-1990?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1991: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1991/etos_kataskevis_eos-1991?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1992: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1992/etos_kataskevis_eos-1992?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1993: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1993/etos_kataskevis_eos-1993?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1994: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1994/etos_kataskevis_eos-1994?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1995: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1995/etos_kataskevis_eos-1995?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1996: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1996/etos_kataskevis_eos-1996?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1997: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1997/etos_kataskevis_eos-1997?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1998: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1998/etos_kataskevis_eos-1998?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  1999: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-1999/etos_kataskevis_eos-1999?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2000: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2000/etos_kataskevis_eos-2000?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2001: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2001/etos_kataskevis_eos-2001?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2002: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2002/etos_kataskevis_eos-2002?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2003: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2003/etos_kataskevis_eos-2003?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2004: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2004/etos_kataskevis_eos-2004?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2005: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2005/etos_kataskevis_eos-2005?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2006: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2006/etos_kataskevis_eos-2006?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2007: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2007/etos_kataskevis_eos-2007?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2008: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2008/etos_kataskevis_eos-2008?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2009: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2009/etos_kataskevis_eos-2009?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2010: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2010/etos_kataskevis_eos-2010?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2011: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2011/etos_kataskevis_eos-2011?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2012: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2012/etos_kataskevis_eos-2012?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2013: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2013/etos_kataskevis_eos-2013?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2014: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2014/etos_kataskevis_eos-2014?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2015: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2015/etos_kataskevis_eos-2015?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2016: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2016/etos_kataskevis_eos-2016?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2017: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2017/etos_kataskevis_eos-2017?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2018: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2018/etos_kataskevis_eos-2018?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2019: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2019/etos_kataskevis_eos-2019?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2020: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2020/etos_kataskevis_eos-2020?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2021: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2021/etos_kataskevis_eos-2021?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2022: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2022/etos_kataskevis_eos-2022?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  2023: 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/etos_kataskevis_apo-2023/etos_kataskevis_eos-2023?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14'}

# %% [markdown]
# The next function takes a webdriver element which is going to be one page from all houses build on a specific year (30 houses per page), in the spitogatos website, and returns a dataframe with the attributes location,price,area,description,floor number,number of rooms, number of bathrooms

# %%
def attributes2(sel_webdriver,df_base):
    """
    Extracts house attributes from a webpage and appends them to a DataFrame.

    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
        df_base (DataFrame): Base DataFrame to append data to.

    Returns:
        DataFrame: Updated DataFrame with extracted attributes.
    """
    
    ignored_exceptions=(NoSuchElementException,StaleElementReferenceException,TimeoutException)
    try:
        #this is a list of webdriver elements one  for each house. Note that we wait until all elements have been located.
        entries=WebDriverWait(sel_webdriver, 10,ignored_exceptions=ignored_exceptions)\
                            .until(expected_conditions.visibility_of_all_elements_located((By.XPATH, "//article[@class='ordered-element']")))
        # for each house now we want to find the floor, number of rooms etc. Again we wait until all elements have been located. 
        # The exact locations for each attribute can be found by inspecting the html code of the website.
        houses_attributes=[]
        i=1
        for house in entries:
            try:
                floor=house.find_element(By.XPATH, ".//ul[@class='tile__info']/li[1]/span/span").text
                rooms=house.find_element(By.XPATH, ".//ul[@class='tile__info']/li[2]/span/span").text
                bathrooms=house.find_element(By.XPATH, ".//ul[@class='tile__info']/li[3]/span/span").text
                
                price=house.find_element(By.XPATH, ".//div[@class='tile__price']/p").text
                
                description_and_area=house.find_element(By.XPATH, ".//div[@class='content__top']/h3[1]").text
                
                location=house.find_element(By.XPATH, ".//div[@class='content__top']/h3[2]").text
                submission_date=house.find_element(By.XPATH, ".//p[@class='tile__updated']/time").text
                description=description_and_area.split(",")[0]
                area=description_and_area.split(",")[1]
                
            #Each of these attributes is a WebDriver element from which we want to extract the html content.
            #Also if the scraper did not find any of these attributes we want their value as np.nan. 
        
            except: 
                description=np.nan
                area=np.nan
                floor=np.nan
                rooms=np.nan
                bathrooms=np.nan
                price=np.nan
                location=np.nan
                submission_date=np.nan
            #Finallly we append to our empty dataframe the extracted attributes.   
            attributes=[location,price,area,description,floor,rooms,bathrooms,submission_date]
            houses_attributes.append(attributes)
            if i%10==0:
                print(f"We scraped entry number: \033[91m{i}\033[0m")
            i=i+1
            #df0=pd.DataFrame({"Location":location, "Price":price,"Total_area":area,"House_type":description,"Floor":floor,"Rooms":rooms,"Bathrooms":bathrooms,"submission_date":submission_date},index=[0])
            #print(df0)
            #df_base=pd.concat([df_base,df0],ignore_index=True)
        return(houses_attributes)
    except:
        input("Solve the captcha and press enter to continue")
        attributes2(sel_webdriver,df_base)

# %% [markdown]
# The next function takes a webdriver element and a year and takes the webdriver element to the correct page to scrape.

# %%
def get_driver(sel_webdriver,year):
    """
    Takes the driver instance to the correct website.

    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
        year: Year for which to fetch data.
    """
    sel_webdriver.get(html_files_years1952_2023[year])

# %% [markdown]
# The next function takes a webdriver element which is configured in the correct webpage containing 30 houses and clicks the next button so that the next 30 houses for that year are loaded.

# %%
def click(sel_webdriver,retries=3):
    """
    Clicks the next page of the pagination to load the next batch of entries.
    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
    """
    page1=sel_webdriver.find_elements(By.XPATH,"//ul[@class='pagination b-pagination']/li[@class='page-item page-arrow']")
    
    for i in range(retries):
        try:
            page1[-1].click()
            return
        except WebDriverException as e:
            logging.warning(f"Click failed on attempt {i + 1}: {e}")
        
    logging.error("Failed to click after multiple attempts.")

# %% [markdown]
# The next function takes a webdriver, a year and a dataframe. It then scrapes information for all house entries build on that year and puts it in a pandas dataframe. It saves the data in a csv file once it is done.
#
# The general algorithm will work as follows:
# 1. First we load the first page of all houses build for a specific year. Each of the pages in this set contains 30 houses and we need to scrape all pages.
# 2. We find the number of pages in the html file of the webpage by doing a .find_elements command.
# 3. We call the attributes2 function on the driver we loaded on the first step. We append the data (including the year) to our initial dataframe.
# 4. If there is more than one page of houses built on that specific year we load the next page with the click function.
# 5. We repeat step 4 until all pages for that year have been scraped.
# 6. Finally we export the data as a csv file.
#
# This concludes the scraping process for a specific year.

# %%
def many_page_scrape(sel_webdriver,df,attribute=None,):
    """
    Scrapes house data for a specific year and appends it to the DataFrame.
    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
        
        df (DataFrame): Base DataFrame to append data to.
    Returns:
        DataFrame: Updated DataFrame with scraped data.
        """
    
    #2. We find the number of pages in the html file of the webpage by doing a .find_elements command.
    page_num,current_page=find_pages(sel_webdriver)
    print(f"the number of total pages to scrape is:{page_num}")
    #3. We call the attributes2 function on the driver we loaded on the first step. We append the data (including the year) to our initial dataframe.
    df1=pd.DataFrame(attributes2(sel_webdriver,df),columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
    
    df=pd.concat([df,df1],ignore_index=True)
    #4. If there is more than one page of houses built on that specific year we load the next page with the click function.
    if  page_num>1:
        
        
        
        for page in range(current_page,page_num):
            print(f"We scraped page {page} of {page_num}")
            click(sel_webdriver)
            current_url=sel_webdriver.current_url
            time.sleep(3)
        #5. We repeat step 4 until all pages for that year have been scraped.    
            df1=pd.DataFrame(attributes2(sel_webdriver,df),columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
    
            
            df=pd.concat([df,df1],ignore_index=True)
            if page%50==0 and attribute!=None:
                path=f"/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_{datetime.date.today()}/Houses_data_{attribute}/Houses_data_page{page-50}_to{page}.csv"
                df.drop_duplicates(inplace=True)
                df.reset_index(drop=True, inplace=True)
                df.to_csv(path)
                df=df.iloc[0:0]
               


            if page==page_num-1 and attribute!=None:
                path=f"/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_{datetime.date.today()}/Houses_data_{attribute}/Houses_data_lastbatch.csv"
                df.drop_duplicates(inplace=True)
                df.reset_index(drop=True, inplace=True)
                df.to_csv(path)
    #print(df)
    return(df)

# %%
def find_pages(sel_webdriver):
    """
    Finds the total number of pages in the current webpage and the current page.
    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
    """
    pages=sel_webdriver.find_elements(By.XPATH,"//a[@class='page-link']")
    current_page=sel_webdriver.find_element(By.XPATH,"//li[@class='page-item active']")
    if len(pages)>0:
        page_num=int(pages[-2].text)
        current_page=int(current_page.text)
    else:
        page_num=1
        current_page=1
    return page_num, current_page

# %% [markdown]
# Now we want to do the same for all years from 1952 to 2023.

# %%
import os

def main():
    """Main function to scrape house data
    Args:
        path (str): Path to save the scraped data.
        
    """
    folder_name = f"Houses_data_{datetime.date.today()}"

    try:
        os.mkdir(folder_name)
        print(f"Folder '{folder_name}' created successfully.")
    except FileExistsError:
        print(f"Folder '{folder_name}' already exists.")
    except OSError as error:
        print(f"Error creating folder '{folder_name}': {error}")
    
    for year in range(2016, 2024):
        #1. First we load the webpage which has all houses build for a specific year. Each of the pages in this webpage contains 30 houses and we need to scrape all pages. 
        get_driver(driver,year)
        df=pd.DataFrame(columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
        df = many_page_scrape(driver, year, df) 
        print(df.shape)
        
        path = f"/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_{datetime.date.today()}/Houses build in {year}_scraped on {datetime.date.today()}.csv"

        df.drop_duplicates(inplace=True)
        df.reset_index(drop=True, inplace=True)
        df["Year_of_construction"]=year
        df.to_csv(path)
        print(f"Data for year {year} saved")
     




main()

# %%
list_of_attributes_heating={"autonomous_heating":"autonomi_thermansi","central_heating":"kentriki_thermansi","individual_heating":"atomiki_thermansi","no_heating":"xwris_thermansi"}

list_of_attributes_kind_of_heating={
"petrol_heating":"thermansi_petrelaio","natural_gas_heating":"thermansi_fisiko_aerio","LPG_heating":"thermansi_igraerio","electrical_heating":"thermansi_revma",
"thermal_storage_heating":"thermansi_thermosisswreftis","wood_headting":"thermansi_sompa","pellet_heating":"thermansi_pellet","heat_pump_heating":"thermansi_antlia_thermansis"
}

list_of_attributes={"with_AC":"me_klimatismo","with_storage_room":"me_apothiki","with_elavator":"me_anelkistira","with_solar_heater":"me_iliako_thermosifona","with_fireplace":"me_tzaki",
"Furnished":"epiplwmeno","with_parking":"me_garage","with_garden":"me_kipo","with_pool":"me_pisina","with_balcony":"me_mpalkoni","last_floor":"retire"}

filters=list_of_attributes_heating|list_of_attributes_kind_of_heating|list_of_attributes

# %%
html_files_years_filters={}
for attribute in filters:
    
    url_solo=f"https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/{filters[attribute]}?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14" 
    
    
    html_files_years_filters[attribute]=url_solo


#soup=BeautifulSoup(html_file,"html5lib")
html_files_years_filters
# Out:
# {'autonomous_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/autonomi_thermansi?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'central_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/kentriki_thermansi?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'individual_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/atomiki_thermansi?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'no_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/xwris_thermansi?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'petrol_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_petrelaio?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'natural_gas_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_fisiko_aerio?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'LPG_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_igraerio?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'electrical_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_revma?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'thermal_storage_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_thermosisswreftis?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'wood_headting': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_sompa?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'pellet_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_pellet?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'heat_pump_heating': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/thermansi_antlia_thermansis?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_AC': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_klimatismo?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_storage_room': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_apothiki?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_elavator': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_anelkistira?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_solar_heater': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_iliako_thermosifona?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_fireplace': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_tzaki?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'Furnished': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/epiplwmeno?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_parking': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_garage?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_garden': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_kipo?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_pool': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_pisina?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'with_balcony': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/me_mpalkoni?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14',
#  'last_floor': 'https://www.spitogatos.gr/pwliseis-katoikies/anazitisi-xarti/retire?gad_source=1&gclid=Cj0KCQjw4MSzBhC8ARIsAPFOuyWdbWoq9MkzYB_9GZ1t8uEdSNmoSlUXErPyIku-g_dip54sBWRoNC0aArmUEALw_wcB&latitudeLow=40.535981&latitudeHigh=40.733210&longitudeLow=22.799034&longitudeHigh=23.120041&zoom=14'}

# %%
def get_driver2(sel_webdriver,attribute):
    """
    Takes the driver instance to the correct website.

    Args:
        sel_webdriver (WebDriver): Selenium WebDriver instance.
        attribute: Attribute for which to fetch data.
    """
    sel_webdriver.get(html_files_years_filters[attribute])

# %%
# ua = UserAgent()
# user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/87.0.4280.88 Safari/537.36-816"
# options = webdriver.ChromeOptions()
# options.add_argument(f'user-agent={user_agent}')
driver=webdriver.Chrome()

# %%
def main2(attribute,dont_start_at_first_page=False):

    if not dont_start_at_first_page:

        
        get_driver2(driver,attribute)
    folder_name =f"/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_{datetime.date.today()}"

    try:
        os.mkdir(folder_name)
        
        print(f"Folder '{folder_name}' created successfully.")
    except FileExistsError:
        print(f"Folder '{folder_name}' already exists.")
    except OSError as error:
        print(f"Error creating folder '{folder_name}': {error}")
    try:
        os.mkdir(f"{folder_name}/Houses_data_{attribute}")
        print(f"Folder Houses_data_{attribute} created successfully.")
    except FileExistsError:
        print(f"Folder Houses_data_{attribute} already exists.")
    except OSError as error:
        print(f"Error creating folder Houses_data_{attribute}: {error}")

    print(f"We are scraping attribute {attribute}")

    df=pd.DataFrame(columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
    df=many_page_scrape(driver,df,attribute=attribute)

# %%
main2("autonomous_heating",dont_start_at_first_page=True)
# Out:
# Folder '/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_2025-05-26' already exists.
# We are scraping attribute autonomous_heating
# 10
# 20
# 30
# 901
# We are on page 801 of 901
# 10
# 20
# 30
# We are on page 802 of 901
# 10
# 20
# 30
# We are on page 803 of 901
# 10
# 20
# 30
# We are on page 804 of 901
# 10
# 20
# 30
# We are on page 805 of 901
# 10
# 20
# 30
# We are on page 806 of 901
# 10
# 20
# 30
# We are on page 807 of 901
# 10
# 20
# 30
# We are on page 808 of 901
# 10
# 20
# 30
# We are on page 809 of 901
# 10
# 20
# 30
# We are on page 810 of 901
# 10
# 20
# 30
# We are on page 811 of 901
# 10
# 20
# 30
# We are on page 812 of 901
# 10
# 20
# 30
# We are on page 813 of 901
# 10
# 20
# 30
# We are on page 814 of 901
# 10
# 20
# 30
# We are on page 815 of 901
# 10
# 20
# 30
# We are on page 816 of 901
# 10
# 20
# 30
# We are on page 817 of 901
# 10
# 20
# 30
# We are on page 818 of 901
# 10
# 20
# 30
# We are on page 819 of 901
# 10
# 20
# 30
# We are on page 820 of 901
# 10
# 20
# 30
# We are on page 821 of 901
# 10
# 20
# 30
# We are on page 822 of 901
# 10
# 20
# 30
# We are on page 823 of 901
# 10
# 20
# 30
# We are on page 824 of 901
# 10
# 20
# 30
# We are on page 825 of 901
# 10
# 20
# 30
# We are on page 826 of 901
# 10
# 20
# 30
# We are on page 827 of 901
# 10
# 20
# 30
# We are on page 828 of 901
# 10
# 20
# 30
# We are on page 829 of 901
# 10
# 20
# 30
# We are on page 830 of 901
# 10
# 20
# 30
# We are on page 831 of 901
# 10
# 20
# 30
# We are on page 832 of 901
# 10
# 20
# 30
# We are on page 833 of 901
# 10
# 20
# 30
# We are on page 834 of 901
# 10
# 20
# 30
# We are on page 835 of 901
# 10
# 20
# 30
# We are on page 836 of 901
# 10
# 20
# 30
# We are on page 837 of 901
# 10
# 20
# 30
# We are on page 838 of 901
# 10
# 20
# 30
# We are on page 839 of 901
# 10
# 20
# 30
# We are on page 840 of 901
# 10
# 20
# 30
# We are on page 841 of 901
# 10
# 20
# 30
# We are on page 842 of 901
# 10
# 20
# 30
# We are on page 843 of 901
# 10
# 20
# 30
# We are on page 844 of 901
# 10
# 20
# 30
# We are on page 845 of 901
# 10
# 20
# 30
# We are on page 846 of 901
# 10
# 20
# 30
# We are on page 847 of 901
# 10
# 20
# 30
# We are on page 848 of 901
# 10
# 20
# 30
# We are on page 849 of 901
# 10
# 20
# 30
# We are on page 850 of 901
# 10
# 20
# 30
# We are on page 851 of 901
# 10
# 20
# 30
# We are on page 852 of 901
# 10
# 20
# 30
# We are on page 853 of 901
# 10
# 20
# 30
# We are on page 854 of 901
# 10
# 20
# 30
# We are on page 855 of 901
# 10
# 20
# 30
# We are on page 856 of 901
# 10
# 20
# 30
# We are on page 857 of 901
# 10
# 20
# 30
# We are on page 858 of 901
# 10
# 20
# 30
# We are on page 859 of 901
# 10
# 20
# 30
# We are on page 860 of 901
# 10
# 20
# 30
# We are on page 861 of 901
# 10
# 20
# 30
# We are on page 862 of 901
# 10
# 20
# 30
# We are on page 863 of 901
# 10
# 20
# 30
# We are on page 864 of 901
# 10
# 20
# 30
# We are on page 865 of 901
# 10
# 20
# 30
# We are on page 866 of 901
# 10
# 20
# 30
# We are on page 867 of 901
# 10
# 20
# 30
# We are on page 868 of 901
# 10
# 20
# 30
# We are on page 869 of 901
# 10
# 20
# 30
# We are on page 870 of 901
# 10
# 20
# 30
# We are on page 871 of 901
# 10
# 20
# 30
# We are on page 872 of 901
# 10
# 20
# 30
# We are on page 873 of 901
# 10
# 20
# 30
# We are on page 874 of 901
# 10
# 20
# 30
# We are on page 875 of 901
# 10
# 20
# 30
# We are on page 876 of 901
# 10
# 20
# 30
# We are on page 877 of 901
# 10
# 20
# 30
# We are on page 878 of 901
# 10
# 20
# 30
# We are on page 879 of 901
# 10
# 20
# 30
# We are on page 880 of 901
# 10
# 20
# 30
# We are on page 881 of 901
# 10
# 20
# 30
# We are on page 882 of 901
# 10
# 20
# 30
# We are on page 883 of 901
# 10
# 20
# 30
# We are on page 884 of 901
# 10
# 20
# 30
# We are on page 885 of 901
# 10
# 20
# 30
# We are on page 886 of 901
# 10
# 20
# 30
# We are on page 887 of 901
# 10
# 20
# 30
# We are on page 888 of 901
# 10
# 20
# 30
# We are on page 889 of 901
# 10
# 20
# 30
# We are on page 890 of 901
# 10
# 20
# 30
# We are on page 891 of 901
# 10
# 20
# 30
# We are on page 892 of 901
# 10
# 20
# 30
# We are on page 893 of 901
# 10
# 20
# 30
# We are on page 894 of 901
# 10
# 20
# 30
# We are on page 895 of 901
# 10
# 20
# 30
# We are on page 896 of 901
# 10
# 20
# 30
# We are on page 897 of 901
# 10
# 20
# 30
# We are on page 898 of 901
# 10
# 20
# 30
# We are on page 899 of 901
# 10
# 20
# 30
# We are on page 900 of 901
# 10
# 20

# %%
filters
# Out:
# {'autonomous_heating': 'autonomi_thermansi',
#  'central_heating': 'kentriki_thermansi',
#  'individual_heating': 'atomiki_thermansi',
#  'no_heating': 'xwris_thermansi',
#  'petrol_heating': 'thermansi_petrelaio',
#  'natural_gas_heating': 'thermansi_fisiko_aerio',
#  'LPG_heating': 'thermansi_igraerio',
#  'electrical_heating': 'thermansi_revma',
#  'thermal_storage_heating': 'thermansi_thermosisswreftis',
#  'wood_headting': 'thermansi_sompa',
#  'pellet_heating': 'thermansi_pellet',
#  'heat_pump_heating': 'thermansi_antlia_thermansis',
#  'with_AC': 'me_klimatismo',
#  'with_storage_room': 'me_apothiki',
#  'with_elavator': 'me_anelkistira',
#  'with_solar_heater': 'me_iliako_thermosifona',
#  'with_fireplace': 'me_tzaki',
#  'Furnished': 'epiplwmeno',
#  'with_parking': 'me_garage',
#  'with_garden': 'me_kipo',
#  'with_pool': 'me_pisina',
#  'with_balcony': 'me_mpalkoni',
#  'last_floor': 'retire'}

# %%
main2('with_parking',dont_start_at_first_page=True)
# Out:
# Folder '/home/tsantaris/OneDrive/Data science and AI stuff/Project spitogatos/Houses_data_2025-06-05' already exists.
# Folder Houses_data_with_parking already exists.
# We are scraping attribute with_parking
# the number of total pages to scrape is:441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 101 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 102 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 103 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 104 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 105 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 106 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 107 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 108 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 109 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 110 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 111 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 112 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 113 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 114 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 115 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 116 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 117 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 118 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 119 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 120 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 121 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 122 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 123 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 124 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 125 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 126 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 127 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 128 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 129 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 130 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 131 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 132 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 133 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 134 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 135 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 136 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 137 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 138 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 139 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 140 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 141 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 142 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 143 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 144 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 145 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 146 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 147 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 148 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 149 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 150 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 151 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 152 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 153 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 154 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 155 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 156 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 157 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 158 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 159 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 160 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 161 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 162 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 163 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 164 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 165 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 166 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 167 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 168 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 169 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 170 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 171 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 172 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 173 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 174 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 175 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 176 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 177 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 178 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 179 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 180 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 181 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 182 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 183 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 184 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 185 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 186 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 187 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 188 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 189 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 190 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 191 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 192 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 193 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 194 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 195 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 196 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 197 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 198 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 199 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 200 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 201 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 202 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 203 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 204 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 205 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 206 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 207 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 208 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 209 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 210 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 211 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 212 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 213 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 214 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 215 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 216 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 217 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 218 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 219 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 220 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 221 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 222 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 223 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 224 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 225 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 226 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 227 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 228 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 229 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 230 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 231 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 232 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 233 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 234 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 235 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 236 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 237 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 238 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 239 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 240 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 241 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 242 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 243 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 244 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 245 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 246 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 247 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 248 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 249 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 250 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 251 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 252 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 253 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 254 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 255 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 256 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 257 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 258 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 259 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 260 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 261 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 262 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 263 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 264 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 265 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 266 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 267 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 268 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 269 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 270 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 271 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 272 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 273 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 274 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 275 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 276 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 277 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 278 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 279 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 280 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 281 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 282 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 283 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 284 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 285 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 286 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 287 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 288 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 289 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 290 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 291 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 292 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 293 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 294 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 295 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 296 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 297 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 298 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 299 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 300 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 301 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 302 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 303 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 304 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 305 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 306 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 307 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 308 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 309 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 310 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 311 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 312 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 313 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 314 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 315 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 316 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 317 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 318 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 319 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 320 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 321 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 322 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 323 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 324 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 325 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 326 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 327 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 328 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 329 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 330 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 331 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 332 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 333 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 334 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 335 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 336 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 337 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 338 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 339 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 340 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 341 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 342 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 343 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 344 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 345 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 346 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 347 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 348 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 349 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 350 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 351 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 352 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 353 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 354 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 355 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 356 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 357 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 358 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 359 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 360 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 361 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 362 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 363 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 364 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 365 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 366 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 367 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 368 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 369 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 370 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 371 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 372 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 373 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 374 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 375 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 376 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 377 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 378 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 379 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 380 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 381 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 382 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 383 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 384 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 385 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 386 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 387 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 388 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 389 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 390 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 391 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 392 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 393 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 394 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 395 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 396 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 397 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 398 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 399 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 400 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 401 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 402 of 441
# We scraped entry number: 10
# We scraped entry number: 20
# We scraped entry number: 30
# We are on page 403 of 441
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 main2('with_parking',dont_start_at_first_page=True)
#
# Cell In[11], line 27, in main2(attribute, dont_start_at_first_page)
#      24 print(f"We are scraping attribute {attribute}")
#      26 df=pd.DataFrame(columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
# ---> 27 df=many_page_scrape(driver,df,attribute=attribute)
#
# Cell In[51], line 37, in many_page_scrape(sel_webdriver, df, attribute)
#      35     time.sleep(3)
#      36 #5. We repeat step 4 until all pages for that year have been scraped.
# ---> 37     df1=pd.DataFrame(attributes2(sel_webdriver,df),columns=["Location", "Price","Total_area","House_type","Floor","Rooms","Bathrooms","submission_date"])
#      40     df=pd.concat([df,df1],ignore_index=True)
#      41     if page%50==0 and attribute!=None:
#
# Cell In[37], line 15, in attributes2(sel_webdriver, df_base)
#      12 ignored_exceptions=(NoSuchElementException,StaleElementReferenceException,TimeoutException)
#      13 #this is a list of webdriver elements one  for each house. Note that we wait until all elements have been located.
#      14 entries=WebDriverWait(sel_webdriver, 10,ignored_exceptions=ignored_exceptions)\
# ---> 15                     .until(expected_conditions.visibility_of_all_elements_located((By.XPATH, "//article[@class='ordered-element']")))
#      16 # for each house now we want to find the floor, number of rooms etc. Again we wait until all elements have been located.
#      17 # The exact locations for each attribute can be found by inspecting the html code of the website.
#      18 houses_attributes=[]
#
# File ~/miniconda3/envs/spitogatos_env/lib/python3.12/site-packages/selenium/webdriver/support/wait.py:105, in WebDriverWait.until(self, method, message)
#     103     if time.monotonic() > end_time:
#     104         break
# --> 105 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
